# %% [markdown]
# # 기초 라이브러리 사용 설명서 2탄 - Pandas

# %% [markdown]
# ## 1. Pandas
# - 행(Row) x 열(Column)로 구성된 2차원 객체를 다루는 데이터 분석 라이브러리로, 대용량의 데이터들을 처리하는데 매우 편리한 도구

# %% [markdown]
# ## 2. Pandas Import
# - Pandas를 사용하기 위해서는 모듈을 import 해야 함
#
#
# - 주로 간결성을 위해 pd라는 축약된 이름으로 사용
#
#
# - Pandas와 Numpy는 같이 쓰이는 경우가 많기 때문에 주로 같이 import

# %%
# Pandas import
import pandas as pd
import numpy as np

# %% [markdown]
# ## 3. Series vs Dataframe

# %% [markdown]
# - Series: 1차원 배열의 형태를 가지며 인덱스라는 한 가지 기준(행)에 의해 데이터가 저장
#
#
# - Dataframe: 2차원 배열의 형태를 가지며 인덱스와 컬럼이라는 두 가지 기준(행x열)에 의해 표 형태처럼 데이터가 저장
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4. Series 요약

# %% [markdown]
# ### 1) Series 정의하기
# - pd.Series()

# %%
Sr = pd.Series([1, 3, -3, -1, 5])
Sr
# Out:
# 0    1
# 1    3
# 2   -3
# 3   -1
# 4    5
# dtype: int64

# %% [markdown]
# ### 2) Series에 있는 자료 확인하기

# %%
# Series 값 확인
Sr.values
# Out:
# array([ 1,  3, -3, -1,  5], dtype=int64)

# %%
# Series 인덱스 확인
Sr.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# Series 자료형 확인
Sr.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# ### 3) 인덱스 변경하기

# %%
# 방법1: pd.Series([값], index=[인덱스명])
Sr = pd.Series([1, 3, -3, -1, 5], index=['a', 'b', 'c', 'd', 'e']) 
Sr
# Out:
# a    1
# b    3
# c   -3
# d   -1
# e    5
# dtype: int64

# %%
# 방법2: 변수명.index = [인덱스명]
Sr.index = ['f', 'g', 'h', 'fa', 'gb']
Sr
# Out:
# f     1
# g     3
# h    -3
# fa   -1
# gb    5
# dtype: int64

# %% [markdown]
# ### 4) Series 인덱스를 대표하는 이름을 따로 설정하기

# %%
# Series 인덱스 이름 설정
Sr.index.name = 'i_names'
Sr
# Out:
# i_names
# f     1
# g     3
# h    -3
# fa   -1
# gb    5
# dtype: int64

# %% [markdown]
# ### 5) Dictionary 자료형을 Series로 변경하기

# %%
# Dictionary의 key -> Series의 index
dict = {'d': 22, 'a': 23, 'y': 24, 'th': 25, 'on': 26}
Sr3 = pd.Series(dict)
Sr3
# Out:
# d     22
# a     23
# y     24
# th    25
# on    26
# dtype: int64

# %% [markdown]
# ## 5. DataFrame 생성

# %% [markdown]
# ### 1) DataFrame 직접 생성하기
# - pd.DataFrame()

# %%
# numpy array 이용
list1 = [[1, 2, 3], [11, 12, 13]]
array1 = np.array(list1)
df_arr = pd.DataFrame(array1, index=['a', 'b'], columns=list('ABC'))
df_arr
# Out:
#     A   B   C
# a   1   2   3
# b  11  12  13

# %%
# dictionary 이용
dic2 = {'col1': [1, 11], 'col2': [2, 22], 'col3': [3, 33]}  # index 명시 불가
df_dic = pd.DataFrame(dic2)
df_dic
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1    11    22    33

# %% [markdown]
# ### 2) 파일을 불러 DataFrame 생성하기
# - pd.read_csv()

# %%
# csv 데이터 가져오기
df = pd.read_csv('./data/train.csv')
df
# Out:
#       index  quality  fixed acidity  volatile acidity  citric acid  \
# 0         0        5            5.6             0.695         0.06
# 1         1        5            8.8             0.610         0.14
# 2         2        5            7.9             0.210         0.39
# 3         3        6            7.0             0.210         0.31
# 4         4        6            7.8             0.400         0.26
# ...     ...      ...            ...               ...          ...
# 5492   5492        5            7.7             0.150         0.29
# 5493   5493        6            6.3             0.180         0.36
# 5494   5494        7            7.8             0.150         0.34
# 5495   5495        5            6.6             0.410         0.31
# 5496   5496        6            7.0             0.350         0.17
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                6.8      0.042                  9.0                  84.0
# 1                2.4      0.067                 10.0                  42.0
# 2                2.0      0.057                 21.0                 138.0
# 3                6.0      0.046                 29.0                 108.0
# 4                9.5      0.059                 32.0                 178.0
# ...              ...        ...                  ...                   ...
# 5492             1.3      0.029                 10.0                  64.0
# 5493             1.2      0.034                 26.0                 111.0
# 5494             1.1      0.035                 31.0                  93.0
# 5495             1.6      0.042                 18.0                 101.0
# 5496             1.1      0.049                  7.0                 119.0
#
#       density    pH  sulphates  alcohol   type
# 0     0.99432  3.44       0.44     10.2  white
# 1     0.99690  3.19       0.59      9.5    red
# 2     0.99176  3.05       0.52     10.9  white
# 3     0.99390  3.26       0.50     10.8  white
# 4     0.99550  3.04       0.43     10.9  white
# ...       ...   ...        ...      ...    ...
# 5492  0.99320  3.35       0.39     10.1  white
# 5493  0.99074  3.16       0.51     11.0  white
# 5494  0.99096  3.07       0.72     11.3  white
# 5495  0.99195  3.13       0.41     10.5  white
# 5496  0.99297  3.13       0.36      9.7  white
#
# [5497 rows x 14 columns]

# %% [markdown]
# ## 6. DataFrame 데이터 확인

# %% [markdown]
# ### 1) 데이터 출력하기
# - .head(): 상위 5개 자료 출력
#
#
# - .tail(): 하위 5개 자료 출력

# %%
print(df.head())
print(df.tail())
# Out:
#    index  quality  fixed acidity  volatile acidity  citric acid  \
# 0      0        5            5.6             0.695         0.06
# 1      1        5            8.8             0.610         0.14
# 2      2        5            7.9             0.210         0.39
# 3      3        6            7.0             0.210         0.31
# 4      4        6            7.8             0.400         0.26
#
#    residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0             6.8      0.042                  9.0                  84.0
# 1             2.4      0.067                 10.0                  42.0
# 2             2.0      0.057                 21.0                 138.0
# 3             6.0      0.046                 29.0                 108.0
# 4             9.5      0.059                 32.0                 178.0
#
#    density    pH  sulphates  alcohol   type
# 0  0.99432  3.44       0.44     10.2  white
# 1  0.99690  3.19       0.59      9.5    red
# 2  0.99176  3.05       0.52     10.9  white
# 3  0.99390  3.26       0.50     10.8  white
# 4  0.99550  3.04       0.43     10.9  white
#       index  quality  fixed acidity  volatile acidity  citric acid  \
# 5492   5492        5            7.7              0.15         0.29
# 5493   5493        6            6.3              0.18         0.36
# 5494   5494        7            7.8              0.15         0.34
# 5495   5495        5            6.6              0.41         0.31
# 5496   5496        6            7.0              0.35         0.17
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 5492             1.3      0.029                 10.0                  64.0
# 5493             1.2      0.034                 26.0                 111.0
# 5494             1.1      0.035                 31.0                  93.0
# 5495             1.6      0.042                 18.0                 101.0
# 5496             1.1      0.049                  7.0                 119.0
#
#       density    pH  sulphates  alcohol   type
# 5492  0.99320  3.35       0.39     10.1  white
# 5493  0.99074  3.16       0.51     11.0  white
# 5494  0.99096  3.07       0.72     11.3  white
# 5495  0.99195  3.13       0.41     10.5  white
# 5496  0.99297  3.13       0.36      9.7  white

# %%
# 출력하길 원하는 양 숫자로 지정 가능
print(df.head(3))   # 상위 3개
print(df.tail(6))   # 하위 6개
# Out:
#    index  quality  fixed acidity  volatile acidity  citric acid  \
# 0      0        5            5.6             0.695         0.06
# 1      1        5            8.8             0.610         0.14
# 2      2        5            7.9             0.210         0.39
#
#    residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0             6.8      0.042                  9.0                  84.0
# 1             2.4      0.067                 10.0                  42.0
# 2             2.0      0.057                 21.0                 138.0
#
#    density    pH  sulphates  alcohol   type
# 0  0.99432  3.44       0.44     10.2  white
# 1  0.99690  3.19       0.59      9.5    red
# 2  0.99176  3.05       0.52     10.9  white
#       index  quality  fixed acidity  volatile acidity  citric acid  \
# 5491   5491        7            6.9              0.34         0.30
# 5492   5492        5            7.7              0.15         0.29
# 5493   5493        6            6.3              0.18         0.36
# 5494   5494        7            7.8              0.15         0.34
# 5495   5495        5            6.6              0.41         0.31
# 5496   5496        6            7.0              0.35         0.17
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 5491             4.7      0.029                 34.0                 148.0
# 5492             1.3      0.029                 10.0                  64.0
# 5493             1.2      0.034                 26.0                 111.0
# 5494             1.1      0.035                 31.0                  93.0
# 5495             1.6      0.042                 18.0                 101.0
# 5496             1.1      0.049                  7.0                 119.0
#
#       density    pH  sulphates  alcohol   type
# 5491  0.99165  3.36       0.49     12.3  white
# 5492  0.99320  3.35       0.39     10.1  white
# 5493  0.99074  3.16       0.51     11.0  white
# 5494  0.99096  3.07       0.72     11.3  white
# 5495  0.99195  3.13       0.41     10.5  white
# 5496  0.99297  3.13       0.36      9.7  white

# %% [markdown]
# ### 2) 행과 열만 출력
# - .index: 인덱스 출력 (행)
#
#
# - .columns: 컬럼 출력 (열)

# %%
print(df.index)
print(df.columns)
# Out:
# RangeIndex(start=0, stop=5497, step=1)
# Index(['index', 'quality', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'type'],
#       dtype='object')

# %% [markdown]
# ### 3) 데이터 값 출력하기
# - .values: 자료의 데이터 값 모두 출력

# %%
df.values
# Out:
# array([[0, 5, 5.6, ..., 0.44, 10.2, 'white'],
#        [1, 5, 8.8, ..., 0.59, 9.5, 'red'],
#        [2, 5, 7.9, ..., 0.52, 10.9, 'white'],
#        ...,
#        [5494, 7, 7.8, ..., 0.72, 11.3, 'white'],
#        [5495, 5, 6.6, ..., 0.41, 10.5, 'white'],
#        [5496, 6, 7.0, ..., 0.36, 9.7, 'white']], dtype=object)

# %% [markdown]
# ### 4) 데이터 특징 확인하기

# %%
# 데이터 종류 출력
df['quality'].unique()
# Out:
# array([5, 6, 7, 8, 4, 3, 9], dtype=int64)

# %%
# 데이터 건수 출력
df['quality'].nunique()
# Out:
# 7

# %%
# 데이터 종류와 건수 출력
value_counts = df['quality'].value_counts()
print(value_counts)
# Out:
# 6    2416
# 5    1788
# 7     924
# 4     186
# 8     152
# 3      26
# 9       5
# Name: quality, dtype: int64

# %%
# 통계 정보 출력
df.describe()
# Out:
#              index      quality  fixed acidity  volatile acidity  citric acid  \
# count  5497.000000  5497.000000    5497.000000       5497.000000  5497.000000
# mean   2748.000000     5.818992       7.210115          0.338163     0.318543
# std    1586.991546     0.870311       1.287579          0.163224     0.145104
# min       0.000000     3.000000       3.800000          0.080000     0.000000
# 25%    1374.000000     5.000000       6.400000          0.230000     0.250000
# 50%    2748.000000     6.000000       7.000000          0.290000     0.310000
# 75%    4122.000000     6.000000       7.700000          0.400000     0.390000
# max    5496.000000     9.000000      15.900000          1.580000     1.660000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     5497.000000  5497.000000          5497.000000           5497.000000
# mean         5.438075     0.055808            30.417682            115.566491
# std          4.756676     0.034653            17.673881             56.288223
# min          0.600000     0.009000             1.000000              6.000000
# 25%          1.800000     0.038000            17.000000             78.000000
# 50%          3.000000     0.047000            29.000000            118.000000
# 75%          8.100000     0.064000            41.000000            155.000000
# max         65.800000     0.610000           289.000000            440.000000
#
#            density           pH    sulphates      alcohol
# count  5497.000000  5497.000000  5497.000000  5497.000000
# mean      0.994673     3.219502     0.530524    10.504918
# std       0.003014     0.160713     0.149396     1.194524
# min       0.987110     2.740000     0.220000     8.000000
# 25%       0.992300     3.110000     0.430000     9.500000
# 50%       0.994800     3.210000     0.510000    10.300000
# 75%       0.996930     3.320000     0.600000    11.300000
# max       1.038980     4.010000     2.000000    14.900000

# %%
# 특정 통계값 출력
print(df.count())   # 모든 컬럼의 count 결과 반환
print(df[['quality', 'fixed acidity']].mean())   # 특정 컬럼의 mean 결과 반환
# Out:
# index                   5497
# quality                 5497
# fixed acidity           5497
# volatile acidity        5497
# citric acid             5497
# residual sugar          5497
# chlorides               5497
# free sulfur dioxide     5497
# total sulfur dioxide    5497
# density                 5497
# pH                      5497
# sulphates               5497
# alcohol                 5497
# type                    5497
# dtype: int64
# quality          5.818992
# fixed acidity    7.210115
# dtype: float64

# %% [markdown]
# ## 7. DataFrame 데이터 정렬

# %% [markdown]
# ### 1) 데이터 값을 기준으로 정렬
# - .sort_values(): 데이터 값을 기준으로 행과 열을 정렬하는 메소드
#     - by: 특정 컬럼을 기준으로 정렬
#     - ascending: 정렬의 방향 (True: 오름차순, False: 내림차순)
#     - axis: 정렬할 대상 축 (=0: 인덱스 기준, =1: 컬럼 기준)

# %%
print(df['alcohol'].sort_values())
# Out:
# 4254     8.00
# 5077     8.00
# 1768     8.40
# 4176     8.40
# 479      8.40
#         ...
# 5160    14.00
# 2142    14.00
# 4964    14.05
# 5340    14.20
# 2787    14.90
# Name: alcohol, Length: 5497, dtype: float64

# %%
print(df.sort_values(by=['alcohol']))   # alcohol 컬럼을 기준으로 정렬
# Out:
#       index  quality  fixed acidity  volatile acidity  citric acid  \
# 4254   4254        3            4.2             0.215         0.23
# 5077   5077        5            4.5             0.190         0.21
# 1768   1768        3           10.4             0.610         0.49
# 4176   4176        5            6.2             0.310         0.23
# 479     479        6           14.3             0.310         0.74
# ...     ...      ...            ...               ...          ...
# 5160   5160        6            5.8             0.390         0.47
# 2142   2142        6            5.2             0.340         0.00
# 4964   4964        7            5.8             0.610         0.01
# 5340   5340        7            6.4             0.350         0.28
# 2787   2787        5           15.9             0.360         0.65
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 4254            5.10      0.041                 64.0                 157.0
# 5077            0.95      0.033                 89.0                 159.0
# 1768            2.10      0.200                  5.0                  16.0
# 4176            3.30      0.052                 34.0                 113.0
# 479             1.80      0.075                  6.0                  15.0
# ...              ...        ...                  ...                   ...
# 5160            7.50      0.027                 12.0                  88.0
# 2142            1.80      0.050                 27.0                  63.0
# 4964            8.40      0.041                 31.0                 104.0
# 5340            1.60      0.037                 31.0                 113.0
# 2787            7.50      0.096                 22.0                  71.0
#
#       density    pH  sulphates  alcohol   type
# 4254  0.99688  3.42       0.44     8.00  white
# 5077  0.99332  3.34       0.42     8.00  white
# 1768  0.99940  3.16       0.63     8.40    red
# 4176  0.99429  3.16       0.48     8.40  white
# 479   1.00080  2.86       0.79     8.40    red
# ...       ...   ...        ...      ...    ...
# 5160  0.99070  3.38       0.45    14.00  white
# 2142  0.99160  3.68       0.79    14.00    red
# 4964  0.99090  3.26       0.72    14.05  white
# 5340  0.98779  3.12       0.40    14.20  white
# 2787  0.99760  2.98       0.84    14.90    red
#
# [5497 rows x 14 columns]

# %% [markdown]
# ### 2) 인덱스 값을 기준으로 정렬
# - .sort_index(): 인덱스 값을 기준으로 행과 열 정렬
#     - ascending: 정렬의 방향 (True: 오름차순, False: 내림차순)

# %%
print(df.sort_index())
# Out:
#       index  quality  fixed acidity  volatile acidity  citric acid  \
# 0         0        5            5.6             0.695         0.06
# 1         1        5            8.8             0.610         0.14
# 2         2        5            7.9             0.210         0.39
# 3         3        6            7.0             0.210         0.31
# 4         4        6            7.8             0.400         0.26
# ...     ...      ...            ...               ...          ...
# 5492   5492        5            7.7             0.150         0.29
# 5493   5493        6            6.3             0.180         0.36
# 5494   5494        7            7.8             0.150         0.34
# 5495   5495        5            6.6             0.410         0.31
# 5496   5496        6            7.0             0.350         0.17
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                6.8      0.042                  9.0                  84.0
# 1                2.4      0.067                 10.0                  42.0
# 2                2.0      0.057                 21.0                 138.0
# 3                6.0      0.046                 29.0                 108.0
# 4                9.5      0.059                 32.0                 178.0
# ...              ...        ...                  ...                   ...
# 5492             1.3      0.029                 10.0                  64.0
# 5493             1.2      0.034                 26.0                 111.0
# 5494             1.1      0.035                 31.0                  93.0
# 5495             1.6      0.042                 18.0                 101.0
# 5496             1.1      0.049                  7.0                 119.0
#
#       density    pH  sulphates  alcohol   type
# 0     0.99432  3.44       0.44     10.2  white
# 1     0.99690  3.19       0.59      9.5    red
# 2     0.99176  3.05       0.52     10.9  white
# 3     0.99390  3.26       0.50     10.8  white
# 4     0.99550  3.04       0.43     10.9  white
# ...       ...   ...        ...      ...    ...
# 5492  0.99320  3.35       0.39     10.1  white
# 5493  0.99074  3.16       0.51     11.0  white
# 5494  0.99096  3.07       0.72     11.3  white
# 5495  0.99195  3.13       0.41     10.5  white
# 5496  0.99297  3.13       0.36      9.7  white
#
# [5497 rows x 14 columns]

# %%
print(df.sort_index(ascending=False))   # 내림차순으로 정렬
# Out:
#       index  quality  fixed acidity  volatile acidity  citric acid  \
# 5496   5496        6            7.0             0.350         0.17
# 5495   5495        5            6.6             0.410         0.31
# 5494   5494        7            7.8             0.150         0.34
# 5493   5493        6            6.3             0.180         0.36
# 5492   5492        5            7.7             0.150         0.29
# ...     ...      ...            ...               ...          ...
# 4         4        6            7.8             0.400         0.26
# 3         3        6            7.0             0.210         0.31
# 2         2        5            7.9             0.210         0.39
# 1         1        5            8.8             0.610         0.14
# 0         0        5            5.6             0.695         0.06
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 5496             1.1      0.049                  7.0                 119.0
# 5495             1.6      0.042                 18.0                 101.0
# 5494             1.1      0.035                 31.0                  93.0
# 5493             1.2      0.034                 26.0                 111.0
# 5492             1.3      0.029                 10.0                  64.0
# ...              ...        ...                  ...                   ...
# 4                9.5      0.059                 32.0                 178.0
# 3                6.0      0.046                 29.0                 108.0
# 2                2.0      0.057                 21.0                 138.0
# 1                2.4      0.067                 10.0                  42.0
# 0                6.8      0.042                  9.0                  84.0
#
#       density    pH  sulphates  alcohol   type
# 5496  0.99297  3.13       0.36      9.7  white
# 5495  0.99195  3.13       0.41     10.5  white
# 5494  0.99096  3.07       0.72     11.3  white
# 5493  0.99074  3.16       0.51     11.0  white
# 5492  0.99320  3.35       0.39     10.1  white
# ...       ...   ...        ...      ...    ...
# 4     0.99550  3.04       0.43     10.9  white
# 3     0.99390  3.26       0.50     10.8  white
# 2     0.99176  3.05       0.52     10.9  white
# 1     0.99690  3.19       0.59      9.5    red
# 0     0.99432  3.44       0.44     10.2  white
#
# [5497 rows x 14 columns]

# %% [markdown]
# ## 8. DataFrame 데이터 선택

# %%
# 슬라이싱 이용
print(df['pH'])
# Out:
# 0       3.44
# 1       3.19
# 2       3.05
# 3       3.26
# 4       3.04
#         ...
# 5492    3.35
# 5493    3.16
# 5494    3.07
# 5495    3.13
# 5496    3.13
# Name: pH, Length: 5497, dtype: float64

# %%
print(df[3:12])   # 3~11 인덱스의 데이터만 출력
print(df[:])      # 전체 데이터 출력
print(df[3:])     # 3부터 끝까지 데이터 출력
print(df[:12])    # 처음부터 11까지 데이터 출력
# Out:
#     index  quality  fixed acidity  volatile acidity  citric acid  \
# 3       3        6            7.0              0.21         0.31
# 4       4        6            7.8              0.40         0.26
# 5       5        6            6.0              0.19         0.37
# 6       6        5            6.1              0.22         0.49
# 7       7        6            7.1              0.38         0.42
# 8       8        5            6.8              0.24         0.31
# 9       9        5            6.8              0.39         0.35
# 10     10        6            8.0              0.18         0.37
# 11     11        7            6.2              0.16         0.33
#
#     residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 3              6.0      0.046                 29.0                 108.0
# 4              9.5      0.059                 32.0                 178.0
# 5              9.7      0.032                 17.0                  50.0
# 6              1.5      0.051                 18.0                  87.0
# 7             11.8      0.041                 32.0                 193.0
# 8             18.3      0.046                 40.0                 142.0
# 9             11.6      0.044                 57.0                 220.0
# 10             0.9      0.049                 36.0                 109.0
# 11             1.1      0.057                 21.0                  82.0
#
#     density    pH  sulphates  alcohol   type
# 3   0.99390  3.26       0.50     10.8  white
# 4   0.99550  3.04       0.43     10.9  white
# 5   0.99320  3.08       0.66     12.0  white
# 6   0.99280  3.30       0.46      9.6  white
# 7   0.99624  3.04       0.49     10.0  white
# 8   1.00000  3.30       0.41      8.7  white
# 9   0.99775  3.07       0.53      9.3  white
# 10  0.99007  2.89       0.44     12.7    red
# 11  0.99100  3.32       0.46     10.9  white
#       index  quality  fixed acidity  volatile acidity  citric acid  \
# 0         0        5            5.6             0.695         0.06
# 1         1        5            8.8             0.610         0.14
# 2         2        5            7.9             0.210         0.39
# 3         3        6            7.0             0.210         0.31
# 4         4        6            7.8             0.400         0.26
# ...     ...      ...            ...               ...          ...
# 5492   5492        5            7.7             0.150         0.29
# 5493   5493        6            6.3             0.180         0.36
# 5494   5494        7            7.8             0.150         0.34
# 5495   5495        5            6.6             0.410         0.31
# 5496   5496        6            7.0             0.350         0.17
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                6.8      0.042                  9.0                  84.0
# 1                2.4      0.067                 10.0                  42.0
# 2                2.0      0.057                 21.0                 138.0
# 3                6.0      0.046                 29.0                 108.0
# 4                9.5      0.059                 32.0                 178.0
# ...              ...        ...                  ...                   ...
# 5492             1.3      0.029                 10.0                  64.0
# 5493             1.2      0.034                 26.0                 111.0
# 5494             1.1      0.035                 31.0                  93.0
# 5495             1.6      0.042                 18.0                 101.0
# 5496             1.1      0.049                  7.0                 119.0
#
#       density    pH  sulphates  alcohol   type
# 0     0.99432  3.44       0.44     10.2  white
# 1     0.99690  3.19       0.59      9.5    red
# 2     0.99176  3.05       0.52     10.9  white
# 3     0.99390  3.26       0.50     10.8  white
# 4     0.99550  3.04       0.43     10.9  white
# ...       ...   ...        ...      ...    ...
# 5492  0.99320  3.35       0.39     10.1  white
# 5493  0.99074  3.16       0.51     11.0  white
# 5494  0.99096  3.07       0.72     11.3  white
# 5495  0.99195  3.13       0.41     10.5  white
# 5496  0.99297  3.13       0.36      9.7  white
#
# [5497 rows x 14 columns]
#       index  quality  fixed acidity  volatile acidity  citric acid  \
# 3         3        6            7.0              0.21         0.31
# 4         4        6            7.8              0.40         0.26
# 5         5        6            6.0              0.19         0.37
# 6         6        5            6.1              0.22         0.49
# 7         7        6            7.1              0.38         0.42
# ...     ...      ...            ...               ...          ...
# 5492   5492        5            7.7              0.15         0.29
# 5493   5493        6            6.3              0.18         0.36
# 5494   5494        7            7.8              0.15         0.34
# 5495   5495        5            6.6              0.41         0.31
# 5496   5496        6            7.0              0.35         0.17
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 3                6.0      0.046                 29.0                 108.0
# 4                9.5      0.059                 32.0                 178.0
# 5                9.7      0.032                 17.0                  50.0
# 6                1.5      0.051                 18.0                  87.0
# 7               11.8      0.041                 32.0                 193.0
# ...              ...        ...                  ...                   ...
# 5492             1.3      0.029                 10.0                  64.0
# 5493             1.2      0.034                 26.0                 111.0
# 5494             1.1      0.035                 31.0                  93.0
# 5495             1.6      0.042                 18.0                 101.0
# 5496             1.1      0.049                  7.0                 119.0
#
#       density    pH  sulphates  alcohol   type
# 3     0.99390  3.26       0.50     10.8  white
# 4     0.99550  3.04       0.43     10.9  white
# 5     0.99320  3.08       0.66     12.0  white
# 6     0.99280  3.30       0.46      9.6  white
# 7     0.99624  3.04       0.49     10.0  white
# ...       ...   ...        ...      ...    ...
# 5492  0.99320  3.35       0.39     10.1  white
# 5493  0.99074  3.16       0.51     11.0  white
# 5494  0.99096  3.07       0.72     11.3  white
# 5495  0.99195  3.13       0.41     10.5  white
# 5496  0.99297  3.13       0.36      9.7  white
#
# [5494 rows x 14 columns]
#     index  quality  fixed acidity  volatile acidity  citric acid  \
# 0       0        5            5.6             0.695         0.06
# 1       1        5            8.8             0.610         0.14
# 2       2        5            7.9             0.210         0.39
# 3       3        6            7.0             0.210         0.31
# 4       4        6            7.8             0.400         0.26
# 5       5        6            6.0             0.190         0.37
# 6       6        5            6.1             0.220         0.49
# 7       7        6            7.1             0.380         0.42
# 8       8        5            6.8             0.240         0.31
# 9       9        5            6.8             0.390         0.35
# 10     10        6            8.0             0.180         0.37
# 11     11        7            6.2             0.160         0.33
#
#     residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0              6.8      0.042                  9.0                  84.0
# 1              2.4      0.067                 10.0                  42.0
# 2              2.0      0.057                 21.0                 138.0
# 3              6.0      0.046                 29.0                 108.0
# 4              9.5      0.059                 32.0                 178.0
# 5              9.7      0.032                 17.0                  50.0
# 6              1.5      0.051                 18.0                  87.0
# 7             11.8      0.041                 32.0                 193.0
# 8             18.3      0.046                 40.0                 142.0
# 9             11.6      0.044                 57.0                 220.0
# 10             0.9      0.049                 36.0                 109.0
# 11             1.1      0.057                 21.0                  82.0
#
#     density    pH  sulphates  alcohol   type
# 0   0.99432  3.44       0.44     10.2  white
# 1   0.99690  3.19       0.59      9.5    red
# 2   0.99176  3.05       0.52     10.9  white
# 3   0.99390  3.26       0.50     10.8  white
# 4   0.99550  3.04       0.43     10.9  white
# 5   0.99320  3.08       0.66     12.0  white
# 6   0.99280  3.30       0.46      9.6  white
# 7   0.99624  3.04       0.49     10.0  white
# 8   1.00000  3.30       0.41      8.7  white
# 9   0.99775  3.07       0.53      9.3  white
# 10  0.99007  2.89       0.44     12.7    red
# 11  0.99100  3.32       0.46     10.9  white

# %%
# loc
df.loc[11, 'density']   # density 컬럼에 11 인덱스에 위치된 값 (명칭기반)
# Out:
# 0.991

# %%
# iloc
df.iloc[2, 3]   # 3번째 행 4번째 열 (위치기반)
# Out:
# 0.21

# %% [markdown]
# ## 9. DataFrame 데이터 생성

# %%
# 데이터 생성
df1 = df
df1['joy'] = 0
rd = pd.DataFrame(np.random.randn(100, 1))
df1['joya'] = rd
df1
# Out:
#       index  quality  fixed acidity  volatile acidity  citric acid  \
# 0         0        5            5.6             0.695         0.06
# 1         1        5            8.8             0.610         0.14
# 2         2        5            7.9             0.210         0.39
# 3         3        6            7.0             0.210         0.31
# 4         4        6            7.8             0.400         0.26
# ...     ...      ...            ...               ...          ...
# 5492   5492        5            7.7             0.150         0.29
# 5493   5493        6            6.3             0.180         0.36
# 5494   5494        7            7.8             0.150         0.34
# 5495   5495        5            6.6             0.410         0.31
# 5496   5496        6            7.0             0.350         0.17
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                6.8      0.042                  9.0                  84.0
# 1                2.4      0.067                 10.0                  42.0
# 2                2.0      0.057                 21.0                 138.0
# 3                6.0      0.046                 29.0                 108.0
# 4                9.5      0.059                 32.0                 178.0
# ...              ...        ...                  ...                   ...
# 5492             1.3      0.029                 10.0                  64.0
# 5493             1.2      0.034                 26.0                 111.0
# 5494             1.1      0.035                 31.0                  93.0
# 5495             1.6      0.042                 18.0                 101.0
# 5496             1.1      0.049                  7.0                 119.0
#
#       density    pH  sulphates  alcohol   type  joy      joya
# 0     0.99432  3.44       0.44     10.2  white    0 -0.519920
# 1     0.99690  3.19       0.59      9.5    red    0 -0.362141
# 2     0.99176  3.05       0.52     10.9  white    0  0.531825
# 3     0.99390  3.26       0.50     10.8  white    0 -0.697335
# 4     0.99550  3.04       0.43     10.9  white    0  1.164489
# ...       ...   ...        ...      ...    ...  ...       ...
# 5492  0.99320  3.35       0.39     10.1  white    0       NaN
# 5493  0.99074  3.16       0.51     11.0  white    0       NaN
# 5494  0.99096  3.07       0.72     11.3  white    0       NaN
# 5495  0.99195  3.13       0.41     10.5  white    0       NaN
# 5496  0.99297  3.13       0.36      9.7  white    0       NaN
#
# [5497 rows x 16 columns]

# %% [markdown]
# ## 10. DataFrame 데이터 변경

# %% [markdown]
# ### 1) 위치 변경
# - .at[행, 열] = 값: 라벨의 이름을 이용하여 원하는 위치의 값 변경
#
#
# - .iat[인덱스번호] = 값: 인덱스 번호를 이용한 위치의 값 변경

# %%
# 라벨 이용, 명칭 기반
df1.at[1, 'quality'] = 3
df1
# Out:
#       index  quality  fixed acidity  volatile acidity  citric acid  \
# 0         0        5            5.6             0.695         0.06
# 1         1        3            8.8             0.610         0.14
# 2         2        5            7.9             0.210         0.39
# 3         3        6            7.0             0.210         0.31
# 4         4        6            7.8             0.400         0.26
# ...     ...      ...            ...               ...          ...
# 5492   5492        5            7.7             0.150         0.29
# 5493   5493        6            6.3             0.180         0.36
# 5494   5494        7            7.8             0.150         0.34
# 5495   5495        5            6.6             0.410         0.31
# 5496   5496        6            7.0             0.350         0.17
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                6.8      0.042                  9.0                  84.0
# 1                2.4      0.067                 10.0                  42.0
# 2                2.0      0.057                 21.0                 138.0
# 3                0.0      0.046                 29.0                 108.0
# 4                9.5      0.059                 32.0                 178.0
# ...              ...        ...                  ...                   ...
# 5492             1.3      0.029                 10.0                  64.0
# 5493             1.2      0.034                 26.0                 111.0
# 5494             1.1      0.035                 31.0                  93.0
# 5495             1.6      0.042                 18.0                 101.0
# 5496             1.1      0.049                  7.0                 119.0
#
#       density    pH  sulphates  alcohol   type  joy      joya
# 0     0.99432  3.44       0.44     10.2  white    0 -0.519920
# 1     0.99690  3.19       0.59      9.5    red    0 -0.362141
# 2     0.99176  3.05       0.52     10.9  white    0  0.531825
# 3     0.99390  3.26       0.50     10.8  white    0 -0.697335
# 4     0.99550  3.04       0.43     10.9  white    0  1.164489
# ...       ...   ...        ...      ...    ...  ...       ...
# 5492  0.99320  3.35       0.39     10.1  white    0       NaN
# 5493  0.99074  3.16       0.51     11.0  white    0       NaN
# 5494  0.99096  3.07       0.72     11.3  white    0       NaN
# 5495  0.99195  3.13       0.41     10.5  white    0       NaN
# 5496  0.99297  3.13       0.36      9.7  white    0       NaN
#
# [5497 rows x 16 columns]

# %%
# 위치 기반
df1.iat[3, 5] = 0
df1
# Out:
#       index  quality  fixed acidity  volatile acidity  citric acid  \
# 0         0        5            5.6             0.695         0.06
# 1         1        3            8.8             0.610         0.14
# 2         2        5            7.9             0.210         0.39
# 3         3        6            7.0             0.210         0.31
# 4         4        6            7.8             0.400         0.26
# ...     ...      ...            ...               ...          ...
# 5492   5492        5            7.7             0.150         0.29
# 5493   5493        6            6.3             0.180         0.36
# 5494   5494        7            7.8             0.150         0.34
# 5495   5495        5            6.6             0.410         0.31
# 5496   5496        6            7.0             0.350         0.17
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                6.8      0.042                  9.0                  84.0
# 1                2.4      0.067                 10.0                  42.0
# 2                2.0      0.057                 21.0                 138.0
# 3                0.0      0.046                 29.0                 108.0
# 4                9.5      0.059                 32.0                 178.0
# ...              ...        ...                  ...                   ...
# 5492             1.3      0.029                 10.0                  64.0
# 5493             1.2      0.034                 26.0                 111.0
# 5494             1.1      0.035                 31.0                  93.0
# 5495             1.6      0.042                 18.0                 101.0
# 5496             1.1      0.049                  7.0                 119.0
#
#       density    pH  sulphates  alcohol   type  joy      joya
# 0     0.99432  3.44       0.44     10.2  white    0 -0.519920
# 1     0.99690  3.19       0.59      9.5    red    0 -0.362141
# 2     0.99176  3.05       0.52     10.9  white    0  0.531825
# 3     0.99390  3.26       0.50     10.8  white    0 -0.697335
# 4     0.99550  3.04       0.43     10.9  white    0  1.164489
# ...       ...   ...        ...      ...    ...  ...       ...
# 5492  0.99320  3.35       0.39     10.1  white    0       NaN
# 5493  0.99074  3.16       0.51     11.0  white    0       NaN
# 5494  0.99096  3.07       0.72     11.3  white    0       NaN
# 5495  0.99195  3.13       0.41     10.5  white    0       NaN
# 5496  0.99297  3.13       0.36      9.7  white    0       NaN
#
# [5497 rows x 16 columns]

# %% [markdown]
# ### 2) 행과 열 교환하기
# - .T: 'Transpose index and columns'의 약자로 index와 column을 전치시킴

# %%
T = df.T
print(T)
# Out:
#                          0         1         2         3         4     \
# index                       0         1         2         3         4
# quality                     5         3         5         6         6
# fixed acidity             5.6       8.8       7.9       7.0       7.8
# volatile acidity        0.695      0.61      0.21      0.21       0.4
# citric acid              0.06      0.14      0.39      0.31      0.26
# residual sugar            6.8       2.4       2.0       0.0       9.5
# chlorides               0.042     0.067     0.057     0.046     0.059
# free sulfur dioxide       9.0      10.0      21.0      29.0      32.0
# total sulfur dioxide     84.0      42.0     138.0     108.0     178.0
# density               0.99432    0.9969   0.99176    0.9939    0.9955
# pH                       3.44      3.19      3.05      3.26      3.04
# sulphates                0.44      0.59      0.52       0.5      0.43
# alcohol                  10.2       9.5      10.9      10.8      10.9
# type                    white       red     white     white     white
# joy                         0         0         0         0         0
# joya                 -0.51992 -0.362141  0.531825 -0.697335  1.164489
#
#                           5         6         7         8         9     ...  \
# index                        5         6         7         8         9  ...
# quality                      6         5         6         5         5  ...
# fixed acidity              6.0       6.1       7.1       6.8       6.8  ...
# volatile acidity          0.19      0.22      0.38      0.24      0.39  ...
# citric acid               0.37      0.49      0.42      0.31      0.35  ...
# residual sugar             9.7       1.5      11.8      18.3      11.6  ...
# chlorides                0.032     0.051     0.041     0.046     0.044  ...
# free sulfur dioxide       17.0      18.0      32.0      40.0      57.0  ...
# total sulfur dioxide      50.0      87.0     193.0     142.0     220.0  ...
# density                 0.9932    0.9928   0.99624       1.0   0.99775  ...
# pH                        3.08       3.3      3.04       3.3      3.07  ...
# sulphates                 0.66      0.46      0.49      0.41      0.53  ...
# alcohol                   12.0       9.6      10.0       8.7       9.3  ...
# type                     white     white     white     white     white  ...
# joy                          0         0         0         0         0  ...
# joya                  0.269129 -1.116874 -0.491008 -0.649314  0.095183  ...
#
#                         5487     5488    5489    5490     5491    5492  \
# index                   5487     5488    5489    5490     5491    5492
# quality                    5        5       6       6        7       5
# fixed acidity            7.3      7.6     5.1    11.1      6.9     7.7
# volatile acidity        0.59     0.27    0.39    0.45     0.34    0.15
# citric acid             0.26     0.32    0.21    0.73      0.3    0.29
# residual sugar           7.2      1.2     1.7     3.2      4.7     1.3
# chlorides               0.07    0.043   0.027   0.066    0.029   0.029
# free sulfur dioxide     35.0     23.0    15.0     6.0     34.0    10.0
# total sulfur dioxide   121.0     72.0    72.0    22.0    148.0    64.0
# density               0.9981  0.99236  0.9894  0.9986  0.99165  0.9932
# pH                      3.37     3.06     3.5    3.17     3.36    3.35
# sulphates               0.49     0.68    0.45    0.66     0.49    0.39
# alcohol                  9.4     10.5    12.5    11.2     12.3    10.1
# type                     red    white   white     red    white   white
# joy                        0        0       0       0        0       0
# joya                     NaN      NaN     NaN     NaN      NaN     NaN
#
#                          5493     5494     5495     5496
# index                    5493     5494     5495     5496
# quality                     6        7        5        6
# fixed acidity             6.3      7.8      6.6      7.0
# volatile acidity         0.18     0.15     0.41     0.35
# citric acid              0.36     0.34     0.31     0.17
# residual sugar            1.2      1.1      1.6      1.1
# chlorides               0.034    0.035    0.042    0.049
# free sulfur dioxide      26.0     31.0     18.0      7.0
# total sulfur dioxide    111.0     93.0    101.0    119.0
# density               0.99074  0.99096  0.99195  0.99297
# pH                       3.16     3.07     3.13     3.13
# sulphates                0.51     0.72     0.41     0.36
# alcohol                  11.0     11.3     10.5      9.7
# type                    white    white    white    white
# joy                         0        0        0        0
# joya                      NaN      NaN      NaN      NaN
#
# [16 rows x 5497 columns]

# %% [markdown]
# ## 11. DataFrame 데이터 결합

# %% [markdown]
# ### 1) concat
# - pd.concat([dataframe, dataframe]): 두 개 이상의 데이터프레임 결합

# %%
df11 = pd.DataFrame([1, 2, 3, 4, 5])
df22 = pd.DataFrame([6, 7, 8, 9, 10])

print(pd.concat([df11, df22]))   # 열로 합치기
print(pd.concat([df11, df22], axis=1))   # 행으로 합치기
# Out:
#     0
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
# 0   6
# 1   7
# 2   8
# 3   9
# 4  10
#    0   0
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %%
df11 = pd.DataFrame({'A': ['a', 'a', 'a'], 'B': ['b', 'b', 'b']}, index = [1, 2, 3])
df22 = pd.DataFrame({'C': ['c', 'c', 'c'], 'D': ['d', 'd', 'd']}, index = [4, 5, 6])
print(pd.concat([df11, df22]))
# Out:
#      A    B    C    D
# 1    a    b  NaN  NaN
# 2    a    b  NaN  NaN
# 3    a    b  NaN  NaN
# 4  NaN  NaN    c    d
# 5  NaN  NaN    c    d
# 6  NaN  NaN    c    d

# %%
df22 = pd.DataFrame({'C': ['c', 'c', 'c'], 'D': ['d', 'd', 'd']}, index = [1, 2, 3])
print(pd.concat([df11, df22], axis=1))
# Out:
#    A  B  C  D
# 1  a  b  c  d
# 2  a  b  c  d
# 3  a  b  c  d

# %%
df11 = pd.DataFrame({'A': ['a', 'a', 'a'], 'B': ['b', 'b', 'b']}, index = [1, 2, 3])
df22 = pd.DataFrame({'A': ['a', 'a', 'a'], 'B': ['b', 'b', 'b']}, index = [4, 5, 6])
print(pd.concat([df11, df22]))
# Out:
#    A  B
# 1  a  b
# 2  a  b
# 3  a  b
# 4  a  b
# 5  a  b
# 6  a  b

# %% [markdown]
# ### 2) append
# - concat과 달리 행으로 결합 가능 (열로 결합 불가능)
#
#
# - dataframe1.append(dataframe2)

# %%
df11 = pd.DataFrame({'A': ['a', 'a', 'a'], 'B': ['b', 'b', 'b']}, index = [1, 2, 3])
df22 = pd.DataFrame({'C': ['c', 'c', 'c'], 'D': ['d', 'd', 'd']}, index = [4, 5, 6])
print(df11.append(df22))
# Out:
#      A    B    C    D
# 1    a    b  NaN  NaN
# 2    a    b  NaN  NaN
# 3    a    b  NaN  NaN
# 4  NaN  NaN    c    d
# 5  NaN  NaN    c    d
# 6  NaN  NaN    c    d
# C:\Users\user\AppData\Local\Temp\ipykernel_5372\2439743418.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   print(df11.append(df22))
